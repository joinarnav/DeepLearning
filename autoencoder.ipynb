# %% [markdown]
# <a href="https://colab.research.google.com/github/joinarnav/DeepLearning/blob/main/autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist

# %% [markdown]
# load the datasets

# %%
(x_train,_), (x_test, _)= mnist.load_data()

# %%
def display_images(images, title, num_images=10):
    plt.figure(figsize=(10, 10))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(images[i], cmap='gray')
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# %%
display_images(x_train, title='Sample MNIST Training Images')

# %%
display_images(x_test, title="test images")

# %% [markdown]
# normalizing the data

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
